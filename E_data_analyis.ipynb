# %%
import pandas as pd

# Load the CSV file from the URL
url = 'https://gist.githubusercontent.com/mattkram/9684863843254402942dfede27af2cb7/raw/2590dd8185b833aacf247c0595edbb07a025a6d7/Smithsonian_VOTW_Holocene_Volcanoes.csv'
volcanoes_df = pd.read_csv(url)

# Display the first 10 rows
print(f"Dataset shape: {volcanoes_df.shape}")
volcanoes_df.head(10)
# Out:
# Dataset shape: (1328, 20)
#                                                  FID  Volcano_Number  \
# 0  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210010
# 1  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210020
# 2  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210030
# 3  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210040
# 4  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211004
# 5  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211010
# 6  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211020
# 7  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211031
# 8  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211030
# 9  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211041
#
#                 Volcano_Name Primary_Volcano_Type  Last_Eruption_Year  \
# 0  West Eifel Volcanic Field       Volcanic field             -8300.0
# ...

# %%
volcanoes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1328 entries, 0 to 1327
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FID                    1328 non-null   object
#  1   Volcano_Number         1328 non-null   int64
#  2   Volcano_Name           1328 non-null   object
#  3   Primary_Volcano_Type   1328 non-null   object
#  4   Last_Eruption_Year     859 non-null    float64
#  5   Country                1328 non-null   object
#  6   Geological_Summary     1328 non-null   object
#  7   Region                 1328 non-null   object
#  8   Subregion              1328 non-null   object
#  9   Latitude               1328 non-null   float64
#  10  Longitude              1328 non-null   float64
#  11  Elevation              1328 non-null   int64
#  12  Tectonic_Setting       1323 non-null   object
#  13  Geologic_Epoch         1328 non-null   object
# ...

# %%
volcanoes_df.describe()
# Out:
#        Volcano_Number  Last_Eruption_Year     Latitude    Longitude  \
# count     1328.000000          859.000000  1328.000000  1328.000000
# mean    297245.543675          747.331781    13.735344    18.435376
# std      49480.343715         2382.612232    31.631671   113.729976
# min     210010.000000       -10450.000000   -78.500000  -179.970000
# 25%     261087.500000          842.500000    -7.216500   -84.133250
# 50%     290355.000000         1907.000000    13.629000    36.150000
# 75%     343022.500000         2001.500000    40.752750   131.442500
# max     390847.000000         2023.000000    85.608000   179.580000
#
#          Elevation
# count  1328.000000
# mean   1686.467620
# std    1610.837208
# min   -5700.000000
# 25%     700.000000
# 50%    1480.500000
# 75%    2406.000000
# max    6879.000000

# %%
display(volcanoes_df.describe())
# Out:
#        Volcano_Number  Last_Eruption_Year     Latitude    Longitude  \
# count     1328.000000          859.000000  1328.000000  1328.000000
# mean    297245.543675          747.331781    13.735344    18.435376
# std      49480.343715         2382.612232    31.631671   113.729976
# min     210010.000000       -10450.000000   -78.500000  -179.970000
# 25%     261087.500000          842.500000    -7.216500   -84.133250
# 50%     290355.000000         1907.000000    13.629000    36.150000
# 75%     343022.500000         2001.500000    40.752750   131.442500
# max     390847.000000         2023.000000    85.608000   179.580000
#
#          Elevation
# count  1328.000000
# mean   1686.467620
# std    1610.837208
# min   -5700.000000
# 25%     700.000000
# 50%    1480.500000
# 75%    2406.000000
# max    6879.000000

# %%
print(volcanoes_df['Elevation'].mode())
# Out:
# 0    1100
# Name: Elevation, dtype: int64

# %%
print(volcanoes_df['Last_Eruption_Year'].mode())
# Out:
# 0    2023.0
# Name: Last_Eruption_Year, dtype: float64

# %%
volcanoes_df.isnull().sum()
# Out:
# FID                        0
# Volcano_Number             0
# Volcano_Name               0
# Primary_Volcano_Type       0
# Last_Eruption_Year       469
# Country                    0
# Geological_Summary         0
# Region                     0
# Subregion                  0
# Latitude                   0
# Longitude                  0
# Elevation                  0
# Tectonic_Setting           5
# Geologic_Epoch             0
# Evidence_Category          1
# Primary_Photo_Link        72
# Primary_Photo_Caption     72
# Primary_Photo_Credit      72
# Major_Rock_Type           25
# GeoLocation                0
# dtype: int64

# %%
volcanoes_df.dtypes
# Out:
# FID                       object
# Volcano_Number             int64
# Volcano_Name              object
# Primary_Volcano_Type      object
# Last_Eruption_Year       float64
# Country                   object
# Geological_Summary        object
# Region                    object
# Subregion                 object
# Latitude                 float64
# Longitude                float64
# Elevation                  int64
# Tectonic_Setting          object
# Geologic_Epoch            object
# Evidence_Category         object
# Primary_Photo_Link        object
# Primary_Photo_Caption     object
# Primary_Photo_Credit      object
# Major_Rock_Type           object
# GeoLocation               object
# dtype: object

# %%
volcanoes_df['Evidence_Category'].unique().tolist()
# Out:
# ['Eruption Dated',
#  'Evidence Credible',
#  'Evidence Uncertain',
#  'Eruption Observed',
#  'Unrest / Holocene',
#  nan]

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.histplot(volcanoes_df['Elevation'], kde=True)
plt.title("Elevation Distribution")
plt.show()

# %%
plt.figure(figsize=(16, 16))
sns.histplot(data=volcanoes_df, x='Elevation', hue='Country', kde=True)
plt.title("Elevation Distribution")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 16))
sns.histplot(data=volcanoes_df, x='Elevation', hue='Country', kde=True, ax=ax)
plt.title("Elevation Distribution")
# Get the legend object created by Seaborn
legend = ax.get_legend()
if legend:
    legend.set_bbox_to_anchor((1.05, 1))
    legend.set_title('Country')
    legend._loc = 2  # 'upper left'
    legend.borderpad = 0.
    legend.set_ncols(2)
fig.tight_layout(rect=[0, 0, 0.85, 1])  # Reserve space for legend
plt.show()

# %%
sns.histplot(volcanoes_df['Last_Eruption_Year'], bins=range(-11000, 2025, 250), kde=True)
plt.title("Eruption Distribution")
plt.show()

# %%
sns.countplot(x='Country', data=volcanoes_df)
plt.title("Country Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 16))
sns.countplot(volcanoes_df['Country'])
plt.title("Country Distribution")
plt.tight_layout()  
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# g:\Codes\Jupyter

# %%
sns.scatterplot(x='Elevation', y='Latitude', data=volcanoes_df)
plt.title("Latitude vs Elevation")
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(x='Evidence_Category', y='Elevation', data=volcanoes_df)
plt.title("Elevation by Evidence_Category")
plt.show()

# %%
pd.crosstab(volcanoes_df['Evidence_Category'], volcanoes_df['Region'])
# Out:
# Region              Africa and Red Sea  Alaska  Antarctica  Atlantic Ocean  \
# Evidence_Category
# Eruption Dated                      17      18           5               6
# Eruption Observed                   26      39          11              19
# Evidence Credible                   63      19           3               2
# Evidence Uncertain                  10       6           8               1
# Unrest / Holocene                    3       1           1               0
#
# Region              Canada and Western USA  Hawaii and Pacific Ocean  \
# Evidence_Category
# Eruption Dated                          41                        13
# Eruption Observed                        5                        14
# Evidence Credible                       13                         1
# Evidence Uncertain                       5                         2
# Unrest / Holocene                        0                         3
#
# Region              Iceland and Arctic Ocean  Indonesia  \
# ...

# %%
correlation = volcanoes_df.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
sns.boxplot(volcanoes_df['Elevation'])
# Out:
# <Axes: ylabel='Elevation'>

# %%
volcanoes_df['Elevation by Latitude'] = volcanoes_df['Elevation'] / volcanoes_df['Latitude']
volcanoes_df.head(10)
# Out:
#                                                  FID  Volcano_Number  \
# 0  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210010
# 1  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210020
# 2  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210030
# 3  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210040
# 4  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211004
# 5  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211010
# 6  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211020
# 7  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211031
# 8  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211030
# 9  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211041
#
#                 Volcano_Name Primary_Volcano_Type  Last_Eruption_Year  \
# 0  West Eifel Volcanic Field       Volcanic field             -8300.0
# ...

# %%
volcanoes_df.columns
# Out:
# Index(['FID', 'Volcano_Number', 'Volcano_Name', 'Primary_Volcano_Type',
#        'Last_Eruption_Year', 'Country', 'Geological_Summary', 'Region',
#        'Subregion', 'Latitude', 'Longitude', 'Elevation', 'Tectonic_Setting',
#        'Geologic_Epoch', 'Evidence_Category', 'Primary_Photo_Link',
#        'Primary_Photo_Caption', 'Primary_Photo_Credit', 'Major_Rock_Type',
#        'GeoLocation', 'Elevation by Latitude'],
#       dtype='object')

# %%
volcanoes_df[['FID',# 'Volcano_Number',
               'Volcano_Name', 'Primary_Volcano_Type',
       'Last_Eruption_Year', 'Country',# 'Geological_Summary',
        'Region', 'Subregion', 'Latitude', 'Longitude', 'Elevation', 'Tectonic_Setting',
       'Geologic_Epoch', 'Evidence_Category',# 'Primary_Photo_Link',
       #'Primary_Photo_Caption', 'Primary_Photo_Credit', 'Major_Rock_Type',
       'GeoLocation', 'Elevation by Latitude']]
# Out:
#                                                     FID  \
# 0     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 2     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 3     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 4     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# ...                                                 ...
# 1323  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1324  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1325  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1326  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1327  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
#
#                             Volcano_Name Primary_Volcano_Type  \
# 0              West Eifel Volcanic Field       Volcanic field
# 1                        Chaine des Puys         Lava dome(s)
# 2                    Olot Volcanic Field       Volcanic field
# ...

# %%
volcanoes_df.drop(['Primary_Photo_Credit'], axis=1)
# Out:
#                                                     FID  Volcano_Number  \
# 0     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210010
# 1     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210020
# 2     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210030
# 3     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210040
# 4     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211004
# ...                                                 ...             ...
# 1323  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221294
# 1324  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221330
# 1325  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          312055
# 1326  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          244021
# 1327  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          371032
#
#                             Volcano_Name Primary_Volcano_Type  \
# ...

# %%
# can reorder columns if needed
df=volcanoes_df[['FID',# 'Volcano_Number',
               'Volcano_Name', 'Primary_Volcano_Type',
       'Last_Eruption_Year', 'Country',# 'Geological_Summary',
        'Region', 'Subregion', 'Latitude', 'Longitude', 'Elevation', 'Tectonic_Setting',
       'Geologic_Epoch', 'Evidence_Category',# 'Primary_Photo_Link',
       #'Primary_Photo_Caption', 'Primary_Photo_Credit', 'Major_Rock_Type',
       'GeoLocation', 'Elevation by Latitude']].copy()

# %%
df.dtypes
# Out:
# FID                       object
# Volcano_Name              object
# Primary_Volcano_Type      object
# Last_Eruption_Year       float64
# Country                   object
# Region                    object
# Subregion                 object
# Latitude                 float64
# Longitude                float64
# Elevation                  int64
# Tectonic_Setting          object
# Geologic_Epoch            object
# Evidence_Category         object
# GeoLocation               object
# Elevation by Latitude    float64
# dtype: object

# %%
df['Region'] = df['Region'].astype(str)

# %%
df = df.rename(columns={'Elevation by Latitude' : 'Elevation_by_Latitude'})

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1323    False
# 1324    False
# 1325    False
# 1326    False
# 1327    False
# Length: 1328, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [FID, Volcano_Name, Primary_Volcano_Type, Last_Eruption_Year, Country, Region, Subregion, Latitude, Longitude, Elevation, Tectonic_Setting, Geologic_Epoch, Evidence_Category, GeoLocation, Elevation_by_Latitude]
# Index: []

# %%
df.loc[df.duplicated(subset=['Volcano_Name'])]
# Out:
#                                                     FID   Volcano_Name  \
# 217   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 218   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 219   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 220   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 227   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 293   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 364   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Sumbing
# 475   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 620   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 631   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 793   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...        Unnamed
# 1028  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...   Santa Isabel
# ...

# %%
df.query('Primary_Volcano_Type == "Submarine"')
# Out:
#                                                     FID  \
# 7     Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 15    Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 183   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 202   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 203   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# ...                                                 ...
# 1317  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1318  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1319  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1321  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1326  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
#
#                             Volcano_Name Primary_Volcano_Type  \
# 7                               Palinuro            Submarine
# 15      Campi Flegrei del Mar di Sicilia            Submarine
# 183                   Boomerang Seamount            Submarine
# ...

# %%
# removing duplicate example
# df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])] \
#    .reset_index(drop=True).copy()

# %%
df['Primary_Volcano_Type'].value_counts()
# Out:
# Primary_Volcano_Type
# Stratovolcano          541
# Volcanic field         151
# Submarine              114
# Stratovolcano(es)      113
# Shield                 100
# Caldera                 71
# Complex                 52
# Pyroclastic cone(s)     36
# Lava dome(s)            28
# Shield(s)               17
# Compound                13
# Fissure vent(s)         12
# Pyroclastic cone        11
# Pyroclastic shield       8
# Caldera(s)               8
# Lava dome                8
# Maar(s)                  7
# Tuff cone(s)             5
# Subglacial               5
# Crater rows              5
# Maar                     5
# Fissure vent             4
# Lava cone                2
# Submarine(es)            2
# Tuff cone                2
# Stratovolcano?           2
# Explosion crater(s)      1
# Lava cone(s)             1
# Cone(s)                  1
# Complex(es)              1
# Tuff ring(s)             1
# Lava cone(es)            1
# Name: count, dtype: int64

# %%
df['Primary_Volcano_Type'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='types')
# Out:
# <Axes: title={'center': 'types'}, xlabel='Primary_Volcano_Type'>

# %%
ax = df['Primary_Volcano_Type'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='types', color = 'olive')
ax.set_xlabel('Primary_Volcano_Type')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Last_Eruption_Year'].plot(kind='hist',
                        bins=50,
                        color='fuchsia',
                        title='Last_Eruption_Year')
plt.ylabel('Frequency in each bin')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Last_Eruption_Year'].plot(kind='kde',
                        title='Last_Eruption_Year')
# Out:
# <Axes: title={'center': 'Last_Eruption_Year'}, ylabel='Density'>

# %%
plt.figure(figsize=(18, 6))
ax = df['Last_Eruption_Year'].plot(kind='kde', title='Last_Eruption_Year')
ax.set_xticks(range(-11000, 2025, 250))
ax.set_xlim(-11000, 2025)   
ax.set_xlabel("Year")
ax.grid(True, linewidth=1)
ax.set_xticklabels(ax.get_xticks(), rotation=90)
# Out:
# [Text(-11000, 0, '-11000'),
#  Text(-10750, 0, '-10750'),
#  Text(-10500, 0, '-10500'),
#  Text(-10250, 0, '-10250'),
#  Text(-10000, 0, '-10000'),
#  Text(-9750, 0, '-9750'),
#  Text(-9500, 0, '-9500'),
#  Text(-9250, 0, '-9250'),
#  Text(-9000, 0, '-9000'),
#  Text(-8750, 0, '-8750'),
#  Text(-8500, 0, '-8500'),
#  Text(-8250, 0, '-8250'),
#  Text(-8000, 0, '-8000'),
#  Text(-7750, 0, '-7750'),
#  Text(-7500, 0, '-7500'),
#  Text(-7250, 0, '-7250'),
#  Text(-7000, 0, '-7000'),
#  Text(-6750, 0, '-6750'),
#  Text(-6500, 0, '-6500'),
#  Text(-6250, 0, '-6250'),
#  Text(-6000, 0, '-6000'),
#  Text(-5750, 0, '-5750'),
#  Text(-5500, 0, '-5500'),
#  Text(-5250, 0, '-5250'),
#  Text(-5000, 0, '-5000'),
#  Text(-4750, 0, '-4750'),
#  Text(-4500, 0, '-4500'),
#  Text(-4250, 0, '-4250'),
#  Text(-4000, 0, '-4000'),
#  Text(-3750, 0, '-3750'),
#  Text(-3500, 0, '-3500'),
#  Text(-3250, 0, '-3250'),
#  Text(-3000, 0, '-3000'),
#  Text(-2750, 0, '-2750'),
#  Text(-2500, 0, '-2500'),
# ...

# %%
ndf=df = df.dropna(subset=['Last_Eruption_Year']).reset_index(drop=True).copy()
ndf.head(10)
# Out:
#                                                  FID  \
# 0  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 1  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 2  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 3  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 4  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 5  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 6  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 7  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 8  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
# 9  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...
#
#                 Volcano_Name Primary_Volcano_Type  Last_Eruption_Year  \
# 0  West Eifel Volcanic Field       Volcanic field             -8300.0
# 1            Chaine des Puys         Lava dome(s)             -4040.0
# 2   Calatrava Volcanic Field       Volcanic field             -3600.0
# 3              Campi Flegrei              Caldera              1538.0
# ...

# %%
ax = sns.scatterplot(x='Elevation', y='Latitude', hue='Last_Eruption_Year', data=ndf, palette='rainbow')
plt.title("Latitude vs Elevation")
# Move legend to the right outside the plot
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df, vars=['Elevation','Latitude','Last_Eruption_Year'], hue='Evidence_Category')
plt.show()

# %%
df.query('Country != "Germany"') \
    .groupby('Country')['Elevation'] \
    .agg(['mean','count']) \
    .query('count >= 5') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 8), title='Mean elevation by Country', color ='red')
# Out:
# <Axes: title={'center': 'Mean elevation by Country'}, ylabel='Country'>

# %%
volcanoes_df [(volcanoes_df['Country'].isin(['Russia', 'United States', 'Indonesia'])) & (volcanoes_df['Elevation'] > volcanoes_df.groupby('Country')['Elevation'].transform('mean')) & (volcanoes_df['Major_Rock_Type'].str.startswith('f') | volcanoes_df['Major_Rock_Type'].str.endswith('e'))]
# Out:
#                                                    FID  Volcano_Number  \
# 31   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          214010
# 320  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          261030
# 321  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          261050
# 322  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          261070
# 323  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          261080
# ..                                                 ...             ...
# 868  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          323100
# 869  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          323110
# 870  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          323120
# 871  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          323150
# 882  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          329010
#
#                  Volcano_Name Primary_Volcano_Type  Last_Eruption_Year  \
# ...

# %%
volcanoes_df['Tectonic_Setting'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 0        > 25 km
# 1        > 25 km
# 2        > 25 km
# 3        > 25 km
# 4        > 25 km
#           ...
# 1323     > 25 km
# 1324    15-25 km
# 1325     > 25 km
# 1326     < 15 km
# 1327     < 15 km
# Name: Tectonic_Setting, Length: 1328, dtype: object

# %%
sns.displot(volcanoes_df[volcanoes_df['Country']=='Russia']['Elevation'])

# %%
sns.displot(volcanoes_df[volcanoes_df['Last_Eruption_Year']>=0]['Elevation'], color="cyan")

# %%
sns.displot(
    data=df,
    x="Elevation",
    col="Evidence_Category",    # one plot per category
    col_wrap=2,          # wrap into 2 columns
    height=4,            # size of each subplot
    binwidth=1000,       # width of bins
    color="cyan"      # nice color
)

plt.show()

# %%
sdf=volcanoes_df [(volcanoes_df['Country'].isin(['United States', 'Indonesia']))]

plt.figure(figsize=(12, 12))
sns.violinplot(data=sdf,
    x='Evidence_Category',
    y='Elevation',
    hue='Country',
    split=True,
    inner='quartile',
    linewidth=1.2)
# Out:
# <Axes: xlabel='Evidence_Category', ylabel='Elevation'>

# %%
sns.lmplot(data=sdf,
    x='Last_Eruption_Year',
    y='Elevation',
    hue='Country',
    lowess=True,
    height=5,
    aspect=1.6,
    scatter_kws={'s': 25, 'alpha': 0.6},
    line_kws={'linewidth': 3})

# %%
sdf.groupby(['Evidence_Category', 'Country'])['Elevation'].mean()
# Out:
# Evidence_Category   Country
# Eruption Dated      Indonesia        1935.000000
#                     United States    1823.827586
# Eruption Observed   Indonesia        1965.868421
#                     United States    1461.327869
# Evidence Credible   Indonesia        1607.538462
#                     United States    1156.500000
# Evidence Uncertain  Indonesia        1547.833333
#                     United States    1257.250000
# Unrest / Holocene   Indonesia        1671.600000
#                     United States    -271.555556
# Name: Elevation, dtype: float64

# %%
# lambda usage
# df_cleaned['race_month'] = df_cleaned['race_day'].str.split('.').str[1].astype(int)
# df_cleaned['race_season'] = df_cleaned['race_month'].apply(
#    lambda x: 'Winter' if x > 11 or x < 3 else
#              'Spring' if x < 6 else
#              'Summer' if x < 9 else
#              'Fall'
# )

# %%
evidence = volcanoes_df['Evidence_Category'].value_counts()
plt.pie(evidence, labels=evidence.index, autopct='%1.1f%%', startangle=90)
plt.title("Evidence Category Distribution")
plt.show()

# %%
plt.figure(figsize=(24, 6))
volcanoes_df.groupby('Latitude')['Elevation'].mean().plot(kind='line', marker = 'o', title='Elevation by Latitude',)
plt.xlabel("Latitude")
plt.ylabel("Elevation")
plt.xticks(rotation=90)
plt.show()
